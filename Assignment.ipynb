# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('Salaries.csv')
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# ## Basic Data Exploration

# %%
#identifying the number of rows and columns in the dataframe 
print(f"Number of rows = {df.shape[0]}")
print(f"Number of columns = {df.shape[1]}")
# Out:
# Number of rows = 148654
# Number of columns = 13

# %%
#number of the non null rows and the data type of each column
df.info()
numerical_columns=['TotalPay', 'BasePay', 'OvertimePay', 'OtherPay', 'Benefits']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
#number of null rows in the data
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %% [markdown]
# ## Descriptive Statistics

# %%
#mean,median,standard deviation,min,max of each column 
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
#mode of each column iloc[0] to get only the first mode
mode=df.mode().iloc[0]
mode
# Out:
# Id                                 1
# EmployeeName               Kevin Lee
# JobTitle            Transit Operator
# BasePay                          0.0
# OvertimePay                      0.0
# OtherPay                         0.0
# Benefits                         0.0
# TotalPay                         0.0
# TotalPayBenefits             7959.18
# Year                          2014.0
# Notes                            NaN
# Agency                 San Francisco
# Status                           NaN
# Name: 0, dtype: object

# %%
#range=max-min
salary_range=df['TotalPay'].max()-df['TotalPay'].min()
print(f'the range of the totalpay is : {salary_range}')
# Out:
# the range of the totalpay is : 568213.56

# %% [markdown]
# ## Data Cleaning

# %%
#dropped status colum and notes colum since both are empty
data=df.drop(columns={'Status','Notes'})

#benefits colum and basepay colum mode is 0 so i fill the null with 0
data.loc[data['BasePay'].isnull(), 'BasePay'] = 0
data.loc[data['Benefits'].isnull(), 'Benefits'] = 0

#overtimepay and otherpay is has a symmetric distribution so i fill the null with the mean 
data['OvertimePay'].fillna(data['OvertimePay'].mean(), inplace=True)
data['OtherPay'].fillna(data['OtherPay'].mean(), inplace=True)
data.isnull().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %% [markdown]
# ## Basic Data Visualization

# %%
#histogram to show the majority of the employees total pay falls in the range of 0 to 10000
plt.figure(figsize=(10, 6))
sns.histplot(data['TotalPay'], bins=30, kde=True, color='navy')
plt.title('Distribution of Total Pay')
plt.xlabel('Total Pay')
plt.ylabel('Frequency')
plt.show()

# %%
#the pie chart shows the percentage of employees across different departments with the highest being the transit operator
plt.figure(figsize=(8, 8))
department_counts = data['JobTitle'].value_counts().head(10)
plt.pie(department_counts, labels=department_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of Employees in Different Departments')
plt.show()

# %% [markdown]
# ## Grouped Analysis

# %%
#the total pay mean for each year
pay_peryear = data.groupby('Year')['TotalPay'].mean()
pay_peryear
# Out:
# Year
# 2011    71744.103871
# 2012    74113.262265
# 2013    77611.443142
# 2014    75463.918140
# Name: TotalPay, dtype: float64

# %%
#the total pay mean according to the job title in each year 
jobpay_peryear = data.groupby(['Year', 'JobTitle'])['TotalPay'].mean()
jobpay_peryear
# Out:
# Year  JobTitle
# 2011  ACCOUNT CLERK                      44035.664337
#       ACCOUNTANT                         47429.268000
#       ACCOUNTANT INTERN                  29031.742917
#       ACUPUNCTURIST                      67594.400000
#       ADMINISTRATIVE ANALYST             63954.867527
#                                             ...
# 2014  Wire Rope Cable Maint Sprv        190575.900000
#       Worker's Comp Supervisor 1         56689.446667
#       Worker's Compensation Adjuster     70636.455385
#       X-Ray Laboratory Aide              51211.566857
#       Youth Comm Advisor                 36465.910000
# Name: TotalPay, Length: 4137, dtype: float64

# %%
#the highest paying job
highest_paying_job = jobpay_peryear.idxmax()
print(f"the highest paying job is {highest_paying_job[1]} in {highest_paying_job[0]} with a value of {jobpay_peryear.loc[highest_paying_job]}")
# Out:
# the highest paying job is GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY in 2011 with a value of 399211.275

# %% [markdown]
# ## Simple Correlation Analysis

# %%
#correlation matrix to know the correlation between each numerical column
correlation_matrix = data[numerical_columns].corr()
correlation_matrix
# Out:
#              TotalPay   BasePay  OvertimePay  OtherPay  Benefits
# TotalPay     1.000000  0.954693     0.504844  0.470482  0.632202
# BasePay      0.954693  1.000000     0.268110  0.281778  0.654153
# OvertimePay  0.504844  0.268110     1.000000  0.316592  0.226161
# OtherPay     0.470482  0.281778     0.316592  1.000000  0.160331
# Benefits     0.632202  0.654153     0.226161  0.160331  1.000000

# %%
#heatmap to visualize the correlation between each numerical column
plt.figure(figsize=(10, 8))
sns.heatmap(data[numerical_columns].corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
#pair plot to identify clusters and potential relationships between different columns like the linear relationship between the total pay and base pay
sns.pairplot(data[numerical_columns])
plt.show()

# %% [markdown]
# # Summary of Insights
#
# ## Overview
# the data set is about the total pay of employees in different departments and how different factories affects there total pay
#
# ## Key Findings
# - the dataset consists of 13 column and rows 148654
# - columns like notes and status are not important and are empty
# - most of the data is numerical except of 3 columns ['EmployeeName','JobTitle','Agency'] are strings
# - according the the histogram the majority of the employees total pay falls in the range of 0 to 10000
# - according to  pie chart shows the percentage the highest of employees in any departments is transit operator
# - the highest mean of total pay in any year is at 2013 with a value of 77611.443142
# - the highest paying job is GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY in 2011 with a value of 399211.275
# - there is a strong positive correlation between the total pay and the base pay the higher your base pay is the higher your total pay will be
# - there is also a good correlation between the base pay and the benefits the higher your base pay is the higher the benefits you will get
